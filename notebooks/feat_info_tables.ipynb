# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.ticker import MultipleLocator
from scipy.stats.stats import pearsonr
from pandas import DataFrame

# %%
    feature_alias = {
        'pW1': 'Ca ii H&K',
        'pW2': 'Si ii λ4130',
        'pW3': 'Mg ii, Fe ii',
        'pW4': 'Fe ii, Si ii',
        'pW5': 'S ii λ5449, λ5622',
        'pW6': 'Si ii λ5972',
        'pW7': 'Si ii λ6355',
        'pW8': 'Ca ii IR triplet'}

# %%
sdss_combined = pd.read_csv('/Users/ellakane/Desktop/research/SN-Spectral-Evolution/results/residual_df.csv', index_col=['feat_name', 'obj_id'])
sdss_combined = sdss_combined.iloc[: , 1:]

# %% [markdown]
# ### goal: table with number of measurements for each feature

# %%
sdss_combined.loc['pW6']
# Out:
#              time   feat_start     feat_end           vel  vel_err  \
# obj_id
# 19128   2454387.5  5630.787447  5932.631261   8144.168668      0.0
# 2916    2453644.5  5646.531964  5944.099777   8791.600710      0.0
# 2017    2453636.5  5679.642639  5968.959191   4701.143496      0.0
# 17186   2454354.5  5613.326552  5934.643199  10166.275984      0.0
# 19968   2454413.5  5667.652975  5850.854624  10655.454406      0.0
# ...           ...          ...          ...           ...      ...
# 21502   2454421.5  5684.971286  5884.760842   9571.296676      0.0
# 3317    2453640.5  5662.898839  5949.109809  10392.083325      0.0
# 13038   2453995.5  5563.893593  5918.709956   7748.627534      0.0
# 2308    2453637.5  5582.524718  5859.399831  12717.853348      0.0
# 2165    2453641.5  5581.097483  5922.016391   8173.439333      0.0
#
#         vel_samperr        pew  pew_err  pew_samperr          area  ...  \
# obj_id                                                              ...
# ...

# %%
sdss_combined.loc['pW1']
# Out:
#              time   feat_start     feat_end           vel  vel_err  \
# obj_id
# 2017    2453636.5  3615.136877  3908.025238  13865.174056      0.0
# 2689    2453637.5  3657.035407  3918.106397  11820.961436      0.0
# 2916    2453644.5  3639.027373  3923.657455  12459.276662      0.0
# 19128   2454387.5  3572.337104  3947.308028  13497.426179      0.0
# 2372    2453637.5  3588.948328  3936.838939  17722.188697      0.0
# ...           ...          ...          ...           ...      ...
# 2308    2453637.5  3685.497575  3943.625936  11726.883884      0.0
# 3080    2453641.5  3500.126736  3923.324201  18882.193352      0.0
# 2165    2453641.5  3654.436498  3944.269698  11735.782795      0.0
# 19968   2454406.5  3507.901777  3921.776287  17654.228010      0.0
# 8719    2453683.5  3552.557347  3932.169859  16685.149802      0.0
#
#         vel_samperr         pew  pew_err  pew_samperr          area  ...  \
# obj_id                                                               ...
# ...

# %%
feat_list = ['pW1', 'pW2', 'pW3', 'pW4', 'pW5', 'pW6', 'pW7', 'pW8']
collect = []
for i in feat_list:
    num = len(sdss_combined.loc[i])
    collect.append([i, num])

# %%
num_of_measure = pd.DataFrame(collect, columns=['feat_name', 'number_measurements'])
num_of_measure
# Out:
#   feat_name  number_measurements
# 0       pW1                  116
# 1       pW2                  119
# 2       pW3                  127
# 3       pW4                  120
# 4       pW5                  112
# 5       pW6                  105
# 6       pW7                   99
# 7       pW8                    3
