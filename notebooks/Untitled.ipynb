# %%
from scipy.ndimage import median_filter
from matplotlib import pyplot as plt
from sndata.csp import DR1

# %%
dr1 = DR1()

# %%
dr1.download_module_data()
# Out:
# Fetching http://cdsarc.u-strasbg.fr/viz-bin/nph-Cat/tar.gz?J/ApJ/773/53
# Fetching https://csp.obs.carnegiescience.edu/data/CSP_spectra_DR1.tgz

# %%
demo_data = next(dr1.iter_data())

# %%
plot_data = demo_data[demo_data['time'] == demo_data['time'][0]]
plt.plot(plot_data['wavelength'], plot_data['flux'])

# %%
m = 
for i in range(100):


    m  = median_filter(m, 10, mode='constant', cval=0)
plt.plot(plot_data['wavelength'], m)
